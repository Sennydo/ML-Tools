# %%
import pandas as pd

# %% [markdown]
# ## Creating data in Pandas

# %%
room_info = pd.DataFrame({'Room number': [10, 201, 312], 'Number of Residents': [2,1,5]})
room_info
# Out:
#    Room number  Number of Residents
# 0           10                    2
# 1          201                    1
# 2          312                    5

# %%
print(room_info)
# Out:
#    Room number  Number of Residents
# 0           10                    2
# 1          201                    1
# 2          312                    5

# %% [markdown]
# Changing indexing

# %%
prod_review = pd.DataFrame({
    'Alex':['I liked it a lot', "Classic"],
    'Mary':['Not the best one', "Not really"]
}, index=['Mars', 'Snickers'])

prod_review
# Out:
#                       Alex              Mary
# Mars      I liked it a lot  Not the best one
# Snickers           Classic        Not really

# %%
cal_housing = pd.read_csv('./sample_data/california_housing_test.csv')
cal_housing
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
cal_housing.shape
# Out:
# (3000, 9)

# %%
cal_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
cal_housing.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
cal_change_indexing = pd.read_csv('./sample_data/california_housing_test.csv', index_col=0)
cal_change_indexing
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.05       37.37                27.0       3885.0           661.0
# -118.30       34.26                43.0       1510.0           310.0
# -117.81       33.78                27.0       3589.0           507.0
# -118.36       33.82                28.0         67.0            15.0
# -119.67       36.33                19.0       1241.0           244.0
# ...             ...                 ...          ...             ...
# -119.86       34.42                23.0       1450.0           642.0
# -118.14       34.06                27.0       5257.0          1082.0
# -119.70       36.30                10.0        956.0           201.0
# -117.12       34.10                40.0         96.0            14.0
# -119.63       34.42                42.0       1765.0           263.0
#
#            population  households  median_income  median_house_value
# longitude
# ...

# %% [markdown]
# # Indexing, Selecting and Assigning

# %%
cal_housing = pd.read_csv('./sample_data/california_housing_test.csv')
cal_housing
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
cal_housing.latitude
# Out:
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
cal_housing['latitude']
# Out:
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %% [markdown]
# Specific Value

# %%
rand_housing_age = cal_housing['housing_median_age'][2]
rand_housing_age
# Out:
# 27.0

# %% [markdown]
# Iloc and loc

# %%
cal_housing.iloc[0] #First Row
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %%
cal_housing.iloc[:,0] #First Column
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
cal_housing.iloc[:,2]
# Out:
# 0       27.0
# 1       43.0
# 2       27.0
# 3       28.0
# 4       19.0
#         ...
# 2995    23.0
# 2996    27.0
# 2997    10.0
# 2998    40.0
# 2999    42.0
# Name: housing_median_age, Length: 3000, dtype: float64

# %%
#Combining

cal_housing.iloc[:4, 2]
# Out:
# 0    27.0
# 1    43.0
# 2    27.0
# 3    28.0
# Name: housing_median_age, dtype: float64

# %%
cal_housing.iloc[2:5, 1:5]
# Out:
#    latitude  housing_median_age  total_rooms  total_bedrooms
# 2     33.78                27.0       3589.0           507.0
# 3     33.82                28.0         67.0            15.0
# 4     36.33                19.0       1241.0           244.0

# %%
#Passing a list
cal_housing.iloc[[3,7,12], [3,7]]
# Out:
#     total_rooms  median_income
# 3          67.0         6.1359
# 7        2310.0         3.2250
# 12       1089.0         4.6900

# %% [markdown]
# Negative index would count from bottom

# %%
cal_housing.iloc[-5:]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# Label based - loc

# %%
cal_housing.loc[0, 'latitude']
# Out:
# 37.37

# %%
cal_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
cal_housing.loc[:, ['housing_median_age', 'total_rooms']]
# Out:
#       housing_median_age  total_rooms
# 0                   27.0       3885.0
# 1                   43.0       1510.0
# 2                   27.0       3589.0
# 3                   28.0         67.0
# 4                   19.0       1241.0
# ...                  ...          ...
# 2995                23.0       1450.0
# 2996                27.0       5257.0
# 2997                10.0        956.0
# 2998                40.0         96.0
# 2999                42.0       1765.0
#
# [3000 rows x 2 columns]

# %%
cal_housing.loc[3:5, ['households', 'median_income']]
# Out:
#    households  median_income
# 3        11.0         6.1359
# 4       237.0         2.9375
# 5       204.0         1.6635

# %%
cal_housing.iloc[0, :]
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %%
cal_housing.loc[0, :]
# Out:
# longitude               -122.0500
# latitude                  37.3700
# housing_median_age        27.0000
# total_rooms             3885.0000
# total_bedrooms           661.0000
# population              1537.0000
# households               606.0000
# median_income              6.6085
# median_house_value    344700.0000
# Name: 0, dtype: float64

# %% [markdown]
# Changing Index

# %%
cal_housing_indexed = cal_housing.set_index('median_income')
cal_housing_indexed
# Out:
#                longitude  latitude  housing_median_age  total_rooms  \
# median_income
# 6.6085           -122.05     37.37                27.0       3885.0
# 3.5990           -118.30     34.26                43.0       1510.0
# 5.7934           -117.81     33.78                27.0       3589.0
# 6.1359           -118.36     33.82                28.0         67.0
# 2.9375           -119.67     36.33                19.0       1241.0
# ...                  ...       ...                 ...          ...
# 1.1790           -119.86     34.42                23.0       1450.0
# 3.3906           -118.14     34.06                27.0       5257.0
# 2.2895           -119.70     36.30                10.0        956.0
# 3.2708           -117.12     34.10                40.0         96.0
# 8.5608           -119.63     34.42                42.0       1765.0
#
#                total_bedrooms  population  households  median_house_value
# median_income
# ...

# %%
cal_housing_indexed.loc[:, 'total_rooms']
# Out:
# median_income
# 6.6085    3885.0
# 3.5990    1510.0
# 5.7934    3589.0
# 6.1359      67.0
# 2.9375    1241.0
#            ...
# 1.1790    1450.0
# 3.3906    5257.0
# 2.2895     956.0
# 3.2708      96.0
# 8.5608    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
cal_housing.median_income == 6.6085
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: median_income, Length: 3000, dtype: bool

# %%
cal_housing.loc[cal_housing.median_income == 6.6085]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0

# %% [markdown]
# # Assigning Data

# %%
cal_housing_new = cal_housing
cal_housing_new['safe'] = 'yes'
cal_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value safe
# 0      1537.0       606.0         6.6085            344700.0  yes
# 1       809.0       277.0         3.5990            176500.0  yes
# 2      1484.0       495.0         5.7934            270500.0  yes
# 3        49.0        11.0         6.1359            330000.0  yes
# 4       850.0       237.0         2.9375             81700.0  yes

# %%
#Assigning indexes but in reverse order

cal_housing_new['back_count'] = range(len(cal_housing_new), 0, -1)
cal_housing_new.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value safe  back_count
# 0      1537.0       606.0         6.6085            344700.0  yes        3000
# 1       809.0       277.0         3.5990            176500.0  yes        2999
# 2      1484.0       495.0         5.7934            270500.0  yes        2998
# 3        49.0        11.0         6.1359            330000.0  yes        2997
# 4       850.0       237.0         2.9375             81700.0  yes        2996
